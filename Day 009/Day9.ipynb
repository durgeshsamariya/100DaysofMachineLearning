# %% [markdown]
# # Day 9 Of #100DaysOfMLCode

# %% [markdown]
# ### Data Loading, Storage,vand File Formats

# %% [markdown]
# #### Reading and writing data in text format

# %%
import pandas as pd

# %%
# !cat ex1.csv
# Out:
# ﻿a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world

# %%
df = pd.read_csv('ex1.csv')
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
pd.read_table('ex1.csv', sep=',')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
# with out headers
pd.read_csv('ex1.csv', header=None)
# Out:
#    0  1  2  3        4
# 0  a  b  c  d  message
# 1  1  2  3  4    hello
# 2  5  6  7  8    world

# %%
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
df = df.append({'a':9, 'b':10, 'c':11, 'd':12, 'message':'durgesh'}, ignore_index=True)
df
# Out:
#    a   b   c   d  message
# 0  1   2   3   4    hello
# 1  5   6   7   8    world
# 2  9  10  11  12  durgesh

# %%
df = df.append(pd.Series([13,14,15,16,'samariya'], index=df.columns ), ignore_index=True)
df
# Out:
#     a   b   c   d   message
# 0   1   2   3   4     hello
# 1   5   6   7   8     world
# 2   9  10  11  12   durgesh
# 3  13  14  15  16  samariya

# %%
#writing data frame in new file
df.to_csv('ex1Output.csv')

# %%
! cat ex1Output.csv
# Out:
# ,a,b,c,d,message
# 0,1,2,3,4,hello
# 1,5,6,7,8,world
# 2,9,10,11,12,durgesh
# 3,13,14,15,16,samariya

# %%
# ignore row index
import sys #using sys.stdout print output in console
df.to_csv(sys.stdout, index=False)
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,durgesh
# 13,14,15,16,samariya

# %% [markdown]
# #### JSON Data

# %%
data_obj = """
{"name": "Durgesh",
 "places_lived": ["India", "Australia"],
 "GitHub": "durgeshsamariya",
 "siblings": [{"name": "XYZ", "age": 30, "GitHub": "xyz"},
              {"name": "ABC", "age": 38,
               "GitHub": ["abc", "abc_abc"]}]
}
"""

# %%
import json
data = json.loads(data_obj)

# %%
data
# Out:
# {'name': 'Durgesh',
#  'places_lived': ['India', 'Australia'],
#  'GitHub': 'durgeshsamariya',
#  'siblings': [{'name': 'XYZ', 'age': 30, 'GitHub': 'xyz'},
#   {'name': 'ABC', 'age': 38, 'GitHub': ['abc', 'abc_abc']}]}

# %%
data['places_lived']
# Out:
# ['India', 'Australia']

# %%
pd.DataFrame(data['siblings'])
# Out:
#            GitHub  age name
# 0             xyz   30  XYZ
# 1  [abc, abc_abc]   38  ABC

# %%
# !cat example.json
# Out:
# {"name": {"0":"a", "1":"b", "2" : "c", "3":"d", "4":"e"}, "age": {"0" : 18, "1" : 15, "2" : 22, "3" : 25, "4" : 20}}

# %%
# read json from file
json_data = pd.read_json('example.json')
json_data
# Out:
#   name  age
# 0    a   18
# 1    b   15
# 2    c   22
# 3    d   25
# 4    e   20

# %%
# this html example is taken from https://datatables.net/examples/data_sources/dom
# !cat example.html
# Out:
# <! This example is take from https://datatables.net/examples/data_sources/dom >
# <table id="example" class="display" style="width:100%">
#         <thead>
#             <tr>
#                 <th>Name</th>
#                 <th>Position</th>
#                 <th>Office</th>
#                 <th>Age</th>
#                 <th>Start date</th>
#                 <th>Salary</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Tiger Nixon</td>
#                 <td>System Architect</td>
#                 <td>Edinburgh</td>
#                 <td>61</td>
#                 <td>2011/04/25</td>
#                 <td>$320,800</td>
#             </tr>
#             <tr>
#                 <td>Garrett Winters</td>
#                 <td>Accountant</td>
#                 <td>Tokyo</td>
#                 <td>63</td>
#                 <td>2011/07/25</td>
#                 <td>$170,750</td>
#             </tr>
#             <tr>
# ...

# %%
html_data = pd.read_html('example.html')

# %%
html_data
# Out:
# [                   Name                       Position         Office  Age  \
#  0           Tiger Nixon               System Architect      Edinburgh   61
#  1       Garrett Winters                     Accountant          Tokyo   63
#  2            Ashton Cox        Junior Technical Author  San Francisco   66
#  3          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
#  4            Airi Satou                     Accountant          Tokyo   33
#  5    Brielle Williamson         Integration Specialist       New York   61
#  6       Herrod Chandler                Sales Assistant  San Francisco   59
#  7        Rhona Davidson         Integration Specialist          Tokyo   55
#  8         Colleen Hurst           Javascript Developer  San Francisco   39
#  9           Sonya Frost              Software Engineer      Edinburgh   23
#  10          Jena Gaines                 Office Manager         London   30
# ...

# %%
len(html_data)
# Out:
# 1

# %%
data = html_data[0]

# %%
data
# Out:
#                    Name                       Position         Office  Age  \
# 0           Tiger Nixon               System Architect      Edinburgh   61
# 1       Garrett Winters                     Accountant          Tokyo   63
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 4            Airi Satou                     Accountant          Tokyo   33
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6       Herrod Chandler                Sales Assistant  San Francisco   59
# 7        Rhona Davidson         Integration Specialist          Tokyo   55
# 8         Colleen Hurst           Javascript Developer  San Francisco   39
# 9           Sonya Frost              Software Engineer      Edinburgh   23
# 10          Jena Gaines                 Office Manager         London   30
# ...

# %%
data.head()
# Out:
#               Name                     Position         Office  Age  \
# 0      Tiger Nixon             System Architect      Edinburgh   61
# 1  Garrett Winters                   Accountant          Tokyo   63
# 2       Ashton Cox      Junior Technical Author  San Francisco   66
# 3     Cedric Kelly  Senior Javascript Developer      Edinburgh   22
# 4       Airi Satou                   Accountant          Tokyo   33
#
#    Start date    Salary
# 0  2011/04/25  $320,800
# 1  2011/07/25  $170,750
# 2  2009/01/12   $86,000
# 3  2012/03/29  $433,060
# 4  2008/11/28  $162,700

# %% [markdown]
# #### Interecting with Database

# %%
import sqlite3

# %%
query = """
    CREATE TABLE example_db
    (name VARCHAR(20), age INTEGER);
"""

# %%
# establish connection
con = sqlite3.connect('mydata.sqlite')

# %%
#execute query
con.execute(query)

# %%
con.commit()

# %%
#insert rows
statment1 = "INSERT INTO example_db VALUES('Durgesh', 27)"
con.execute(statment1)
con.commit()

# %%
# add many row at once

rows_value = [("ABC", 25), ("XYZ", 20), ("John", 30)]
statement2 = "INSERT INTO example_db VALUES(?,?)"
con.executemany(statement2, rows_value)

# %%
con.commit()

# %%
#get all values from database
statment3 = con.execute('select * from example_db')
rows = statment3.fetchall()

# %%
rows
# Out:
# [('Durgesh', 27), ('ABC', 25), ('XYZ', 20), ('John', 30)]

# %%
statment3.description
# Out:
# (('name', None, None, None, None, None, None),
#  ('age', None, None, None, None, None, None))

# %%
names = pd.DataFrame(rows, columns=[x[0] for x in statment3.description])
names
# Out:
#       name  age
# 0  Durgesh   27
# 1      ABC   25
# 2      XYZ   20
# 3     John   30
